# %%
import pandas as pd

# %%
df_1 = pd.read_excel("dataset_1.xlsx")

# %%
print(df_1.head())
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
print(df_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB
# None

# %%
df_2 = pd.read_excel("dataset_2.xlsx")

# %%
print(df_2.head())
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df_3 = pd.read_excel("dataset_3.xlsx")

# %%
print(df_3.head())
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620 2011-01-29       1   0     1   1    False        6           1
# 1      621 2011-01-29       1   0     1   2    False        6           1
# 2      622 2011-01-29       1   0     1   3    False        6           1
# 3      623 2011-01-29       1   0     1   4    False        6           1
# 4      624 2011-01-29       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
print(df_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB
# None

# %%
print(df_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB
# None

# %%
print(df_3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB
# None

# %%
df_1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
df_1['dteday'] = pd.to_datetime(df_1['dteday'], format='%d-%m-%Y')
df_1['yr']=df_1['dteday'].dt.year
df_1['mnth']=df_1['dteday'].dt.month
df_1['dteday']=df_1['dteday'].dt.day

# %%
df_1
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       1       1  2011     1   0    False        6           1
# 1          2       1       1  2011     1   1    False        6           1
# 2          3       1       1  2011     1   2    False        6           1
# 3          4       1       1  2011     1   3    False        6           1
# 4          5       1       1  2011     1   4    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 605      606      28       1  2011     1  11    False        5           3
# 606      607      28       1  2011     1  12    False        5           3
# 607      608      28       1  2011     1  13    False        5           3
# 608      609      28       1  2011     1  14    False        5           3
# 609      610      28       1  2011     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# ...

# %%
df_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df_1.drop(columns=['yr', 'mnth',"season"], errors='ignore', inplace=True)

# %%
df_1
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit  temp
# 0          1       1   0    False        6           1  0.24
# 1          2       1   1    False        6           1  0.22
# 2          3       1   2    False        6           1  0.22
# 3          4       1   3    False        6           1  0.24
# 4          5       1   4    False        6           1  0.24
# ..       ...     ...  ..      ...      ...         ...   ...
# 605      606      28  11    False        5           3  0.18
# 606      607      28  12    False        5           3  0.18
# 607      608      28  13    False        5           3  0.18
# 608      609      28  14    False        5           3  0.22
# 609      610      28  15    False        5           2  0.20
#
# [610 rows x 7 columns]

# %%
df_1.drop_duplicates(inplace=True)

# %%
df_1
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit  temp
# 0          1       1   0    False        6           1  0.24
# 1          2       1   1    False        6           1  0.22
# 2          3       1   2    False        6           1  0.22
# 3          4       1   3    False        6           1  0.24
# 4          5       1   4    False        6           1  0.24
# ..       ...     ...  ..      ...      ...         ...   ...
# 605      606      28  11    False        5           3  0.18
# 606      607      28  12    False        5           3  0.18
# 607      608      28  13    False        5           3  0.18
# 608      609      28  14    False        5           3  0.22
# 609      610      28  15    False        5           2  0.20
#
# [610 rows x 7 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int32
#  2   hr          610 non-null    int64
#  3   holiday     610 non-null    bool
#  4   weekday     610 non-null    int64
#  5   weathersit  610 non-null    int64
#  6   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int32(1), int64(4)
# memory usage: 26.9 KB

# %%
missing_values = df_1.isnull().sum()

# %%
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  instant       0
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df_1.fillna(df_1.median(numeric_only=True), inplace=True)

# %%
df_1
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit  temp
# 0          1       1   0    False        6           1  0.24
# 1          2       1   1    False        6           1  0.22
# 2          3       1   2    False        6           1  0.22
# 3          4       1   3    False        6           1  0.24
# 4          5       1   4    False        6           1  0.24
# ..       ...     ...  ..      ...      ...         ...   ...
# 605      606      28  11    False        5           3  0.18
# 606      607      28  12    False        5           3  0.18
# 607      608      28  13    False        5           3  0.18
# 608      609      28  14    False        5           3  0.22
# 609      610      28  15    False        5           2  0.20
#
# [610 rows x 7 columns]

# %%
df_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df_2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df_2.drop(columns=['Unnamed: 0'], errors='ignore', inplace=True)

# %%
df_2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   atemp       599 non-null    float64
#  2   hum         610 non-null    float64
#  3   windspeed   610 non-null    float64
#  4   casual      610 non-null    int64
#  5   registered  610 non-null    int64
#  6   cnt         610 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 33.5 KB

# %%
missing_values = df_2.isnull().sum()

# %%
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df_2["atemp"]=df_2["atemp"].fillna(df_2["atemp"].mean())

# %%
df_2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df=pd.merge(df_1,df_2, on= "instant", how= "inner")

# %%
df
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1       1   0    False        6           1  0.24  0.2879  0.81
# 1          2       1   1    False        6           1  0.22  0.2727  0.80
# 2          3       1   2    False        6           1  0.22  0.2727  0.80
# 3          4       1   3    False        6           1  0.24  0.2879  0.75
# 4          5       1   4    False        6           1  0.24  0.2879  0.75
# ..       ...     ...  ..      ...      ...         ...   ...     ...   ...
# 605      606      28  11    False        5           3  0.18  0.2121  0.93
# 606      607      28  12    False        5           3  0.18  0.2121  0.93
# 607      608      28  13    False        5           3  0.18  0.2121  0.93
# 608      609      28  14    False        5           3  0.22  0.2727  0.80
# 609      610      28  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# ...

# %%
df["temp1"]=(df["temp"]+df["atemp"])/2

# %%
df
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1       1   0    False        6           1  0.24  0.2879  0.81
# 1          2       1   1    False        6           1  0.22  0.2727  0.80
# 2          3       1   2    False        6           1  0.22  0.2727  0.80
# 3          4       1   3    False        6           1  0.24  0.2879  0.75
# 4          5       1   4    False        6           1  0.24  0.2879  0.75
# ..       ...     ...  ..      ...      ...         ...   ...     ...   ...
# 605      606      28  11    False        5           3  0.18  0.2121  0.93
# 606      607      28  12    False        5           3  0.18  0.2121  0.93
# 607      608      28  13    False        5           3  0.18  0.2121  0.93
# 608      609      28  14    False        5           3  0.22  0.2727  0.80
# 609      610      28  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt    temp1
# ...

# %%
df.drop(columns=['temp','atemp'], errors='ignore', inplace=True)

# %%
df
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  \
# 0          1       1   0    False        6           1  0.81     0.0000
# 1          2       1   1    False        6           1  0.80     0.0000
# 2          3       1   2    False        6           1  0.80     0.0000
# 3          4       1   3    False        6           1  0.75     0.0000
# 4          5       1   4    False        6           1  0.75     0.0000
# ..       ...     ...  ..      ...      ...         ...   ...        ...
# 605      606      28  11    False        5           3  0.93     0.1045
# 606      607      28  12    False        5           3  0.93     0.1045
# 607      608      28  13    False        5           3  0.93     0.1045
# 608      609      28  14    False        5           3  0.80     0.0000
# 609      610      28  15    False        5           2  0.86     0.0000
#
#      casual  registered  cnt    temp1
# 0         3          13   16  0.26395
# ...

# %%
df.head()
# Out:
#    instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  casual  \
# 0        1       1   0    False        6           1  0.81        0.0       3
# 1        2       1   1    False        6           1  0.80        0.0       8
# 2        3       1   2    False        6           1  0.80        0.0       5
# 3        4       1   3    False        6           1  0.75        0.0       3
# 4        5       1   4    False        6           1  0.75        0.0       0
#
#    registered  cnt    temp1
# 0          13   16  0.26395
# 1          32   40  0.24635
# 2          27   32  0.24635
# 3          10   13  0.26395
# 4           1    1  0.26395

# %%
df.describe().T
# Out:
#             count        mean         std   min       25%        50%  \
# instant     610.0  305.500000  176.236111  1.00  153.2500  305.50000
# dteday      610.0   13.824590    7.803859  1.00    7.0000   14.00000
# hr          610.0   11.795082    6.852107  0.00    6.0000   12.00000
# weekday     610.0    2.977049    2.054943  0.00    1.0000    3.00000
# weathersit  610.0    1.477049    0.643496  1.00    1.0000    1.00000
# hum         610.0    0.562475    0.175440  0.21    0.4325    0.52000
# windspeed   610.0    0.204851    0.121806  0.00    0.1045    0.19400
# casual      610.0    4.501639    6.319945  0.00    0.0000    2.00000
# registered  610.0   51.068852   47.021204  0.00   14.0000   43.00000
# cnt         610.0   55.570492   49.316802  1.00   16.0000   47.00000
# temp1       610.0    0.198410    0.077859  0.01    0.1482    0.19605
#
#                   75%        max
# instant     457.75000  610.00000
# dteday       21.00000   28.00000
# hr           18.00000   23.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int32
#  2   hr          610 non-null    int64
#  3   holiday     610 non-null    bool
#  4   weekday     610 non-null    int64
#  5   weathersit  610 non-null    int64
#  6   hum         610 non-null    float64
#  7   windspeed   610 non-null    float64
#  8   casual      610 non-null    int64
#  9   registered  610 non-null    int64
#  10  cnt         610 non-null    int64
#  11  temp1       610 non-null    float64
# dtypes: bool(1), float64(3), int32(1), int64(7)
# memory usage: 50.8 KB

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

sns.lineplot(df,ax=axes[0, 1])
axes[0, 1].set_title('Line Plot')

sns.histplot(df, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Histogram with KDE')


sns.boxplot(df,ax=axes[1, 0]) 
axes[1, 0].set_title('Box Plot')

sns.kdeplot(df,ax=axes[2,0])
axes[2,0].set_title('kdeplot')

sns.violinplot(df,ax=axes[1, 1]) 
axes[1, 1].set_title('Violin Plot')


sns.heatmap(df.corr(), annot=True, cmap='coolwarm', ax=axes[2, 1])
axes[2, 1].set_title('Heatmap')

plt.tight_layout()

plt.show()

# %%
df_3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
df.head()
# Out:
#    instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  casual  \
# 0        1       1   0    False        6           1  0.81        0.0       3
# 1        2       1   1    False        6           1  0.80        0.0       8
# 2        3       1   2    False        6           1  0.80        0.0       5
# 3        4       1   3    False        6           1  0.75        0.0       3
# 4        5       1   4    False        6           1  0.75        0.0       0
#
#    registered  cnt    temp1
# 0          13   16  0.26395
# 1          32   40  0.24635
# 2          27   32  0.24635
# 3          10   13  0.26395
# 4           1    1  0.26395

# %%
df_3['dteday'] = df_3['dteday'].astype('object')

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
missing_values = df_3.isnull().sum()

# %%
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_3.fillna(df_3.mean(numeric_only=True), inplace=True)

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df_3["temp1"]=(df_3["temp"]+df_3["atemp"])/2

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# ...

# %%
df_3.drop(columns=['temp','atemp'], errors='ignore', inplace=True)

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit   hum  windspeed  casual  registered  cnt    temp1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int32
#  2   hr          610 non-null    int64
#  3   holiday     610 non-null    bool
#  4   weekday     610 non-null    int64
#  5   weathersit  610 non-null    int64
#  6   hum         610 non-null    float64
#  7   windspeed   610 non-null    float64
#  8   casual      610 non-null    int64
#  9   registered  610 non-null    int64
#  10  cnt         610 non-null    int64
#  11  temp1       610 non-null    float64
# dtypes: bool(1), float64(3), int32(1), int64(7)
# memory usage: 50.8 KB

# %%
missing_values = df_3.isnull().sum()

# %%
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# temp1         0
# dtype: int64

# %%
df_3.fillna(df_3.mean(numeric_only=True), inplace=True)

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit   hum  windspeed  casual  registered  cnt    temp1
# ...

# %%
df_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  2011-01-29 00:00:00       1   0     1   1    False        6
# 1        621  2011-01-29 00:00:00       1   0     1   2    False        6
# 2        622  2011-01-29 00:00:00       1   0     1   3    False        6
# 3        623  2011-01-29 00:00:00       1   0     1   4    False        6
# 4        624  2011-01-29 00:00:00       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit   hum  windspeed  casual  registered  cnt    temp1
# ...

# %%
df_3['dteday']=pd.to_datetime(df_3['dteday'])
df_3['yr']=df_3['dteday'].dt.year
df_3['mnth']=df_3['dteday'].dt.month
df_3['dteday']=df_3['dteday'].dt.day

# %%
df_3
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620      29       1  2011     1   1    False        6           1
# 1        621      29       1  2011     1   2    False        6           1
# 2        622      29       1  2011     1   3    False        6           1
# 3        623      29       1  2011     1   4    False        6           1
# 4        624      29       1  2011     1   6    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 385      615      28       1  2011     1  20    False        5           2
# 386      616      28       1  2011     1  21    False        5           2
# 387      617      28       1  2011     1  22    False        5           1
# 388      618      28       1  2011     1  23    False        5           1
# 389      619      29       1  2011     1   0    False        6           1
#
#       hum  windspeed  casual  registered  cnt    temp1
# ...

# %%
df_final=pd.concat([df, df_3], axis=0, ignore_index=True)

# %%
df_final
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  \
# 0          1       1   0    False        6           1  0.81     0.0000
# 1          2       1   1    False        6           1  0.80     0.0000
# 2          3       1   2    False        6           1  0.80     0.0000
# 3          4       1   3    False        6           1  0.75     0.0000
# 4          5       1   4    False        6           1  0.75     0.0000
# ..       ...     ...  ..      ...      ...         ...   ...        ...
# 995      615      28  20    False        5           2  0.70     0.1940
# 996      616      28  21    False        5           2  0.75     0.1343
# 997      617      28  22    False        5           1  0.65     0.3582
# 998      618      28  23    False        5           1  0.60     0.2239
# 999      619      29   0    False        6           1  0.64     0.3582
#
#      casual  registered  cnt    temp1  season      yr  mnth
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   int32
#  2   hr          1000 non-null   int64
#  3   holiday     1000 non-null   bool
#  4   weekday     1000 non-null   int64
#  5   weathersit  1000 non-null   int64
#  6   hum         1000 non-null   float64
#  7   windspeed   1000 non-null   float64
#  8   casual      1000 non-null   int64
#  9   registered  1000 non-null   int64
#  10  cnt         1000 non-null   int64
#  11  temp1       1000 non-null   float64
#  12  season      390 non-null    float64
#  13  yr          390 non-null    float64
#  14  mnth        390 non-null    float64
# dtypes: bool(1), float64(6), int32(1), int64(7)
# memory usage: 106.6 KB

# %%
df_final.head()
# Out:
#    instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  casual  \
# 0        1       1   0    False        6           1  0.81        0.0       3
# 1        2       1   1    False        6           1  0.80        0.0       8
# 2        3       1   2    False        6           1  0.80        0.0       5
# 3        4       1   3    False        6           1  0.75        0.0       3
# 4        5       1   4    False        6           1  0.75        0.0       0
#
#    registered  cnt    temp1  season  yr  mnth
# 0          13   16  0.26395     NaN NaN   NaN
# 1          32   40  0.24635     NaN NaN   NaN
# 2          27   32  0.24635     NaN NaN   NaN
# 3          10   13  0.26395     NaN NaN   NaN
# 4           1    1  0.26395     NaN NaN   NaN

# %%
df_final.describe().T
# Out:
#              count         mean         std      min          25%         50%  \
# instant     1000.0   500.500000  288.819436     1.00   250.750000   500.50000
# dteday      1000.0    12.992000    8.656724     1.00     6.000000    11.00000
# hr          1000.0    11.753000    6.899101     0.00     6.000000    12.00000
# weekday     1000.0     2.982000    2.091423     0.00     1.000000     3.00000
# weathersit  1000.0     1.480000    0.651171     1.00     1.000000     1.00000
# hum         1000.0     0.582480    0.187977     0.21     0.440000     0.55000
# windspeed   1000.0     0.194931    0.129126     0.00     0.104500     0.16420
# casual      1000.0     4.921000    7.643899     0.00     0.000000     3.00000
# registered  1000.0    53.383000   47.893968     0.00    15.000000    46.00000
# cnt         1000.0    58.304000   50.985558     1.00    16.000000    49.00000
# temp1       1000.0     0.208863    0.075866     0.01     0.157587     0.20605
# ...

# %%
df_final.isnull().sum()
# Out:
# instant         0
# dteday          0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# temp1           0
# season        610
# yr            610
# mnth          610
# dtype: int64

# %%
df_final["season"]=df_final["season"].fillna(df_final["season"].mean())

# %%
df_final
# Out:
#      instant  dteday  hr  holiday  weekday  weathersit   hum  windspeed  \
# 0          1       1   0    False        6           1  0.81     0.0000
# 1          2       1   1    False        6           1  0.80     0.0000
# 2          3       1   2    False        6           1  0.80     0.0000
# 3          4       1   3    False        6           1  0.75     0.0000
# 4          5       1   4    False        6           1  0.75     0.0000
# ..       ...     ...  ..      ...      ...         ...   ...        ...
# 995      615      28  20    False        5           2  0.70     0.1940
# 996      616      28  21    False        5           2  0.75     0.1343
# 997      617      28  22    False        5           1  0.65     0.3582
# 998      618      28  23    False        5           1  0.60     0.2239
# 999      619      29   0    False        6           1  0.64     0.3582
#
#      casual  registered  cnt    temp1  season      yr  mnth
# ...

# %%
df_final.isnull().sum()
# Out:
# instant         0
# dteday          0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# temp1           0
# season          0
# yr            610
# mnth          610
# dtype: int64

# %%
median_values= df.median()

# %%
print("Median values for all numeric columns:")
print(median_values)
# Out:
# Median values for all numeric columns:
# instant       305.50000
# dteday         14.00000
# hr             12.00000
# holiday         0.00000
# weekday         3.00000
# weathersit      1.00000
# hum             0.52000
# windspeed       0.19400
# casual          2.00000
# registered     43.00000
# cnt            47.00000
# temp1           0.19605
# dtype: float64

# %%
mean_values= df.mean()

# %%
print("Mean values for all numeric columns:")
print(mean_values)
# Out:
# Mean values for all numeric columns:
# instant       305.500000
# dteday         13.824590
# hr             11.795082
# holiday         0.039344
# weekday         2.977049
# weathersit      1.477049
# hum             0.562475
# windspeed       0.204851
# casual          4.501639
# registered     51.068852
# cnt            55.570492
# temp1           0.198410
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df_final, x="windspeed",kde=True, color="Black", label="Windspeed")
sns.histplot(data=df_final, x="temp1", kde=True,color="yellow", label="Temperature")
plt.legend()
plt.title("Distribution of Windspeed and Temperature")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
features = ['hr', 'weathersit','weekday','yr', 'weekday'] 
  
plt.subplots(figsize=(20, 10)) 
for i, col in enumerate(features): 
    plt.subplot(2, 3, i + 1) 
    df_final.groupby(col).mean()['cnt'].plot.bar() 
plt.show()

# %%
features = ['temp1', 'windspeed']

plt.subplots(figsize=(15, 5)) 
for i, col in enumerate(features):
    plt.subplot(1, 2, i + 1) 
    sns.boxplot(y=df_final[col]) 
    plt.title(f'Boxplot of {col}')  
plt.tight_layout() 
plt.show()

# %%
features = ['dteday', 'hum', 'registered', 'cnt'] 
  
plt.subplots(figsize=(15, 10)) 
for i, col in enumerate(features): 
    plt.subplot(2, 2, i + 1) 
    sns.boxplot(df_final[col])
    plt.title(col)
plt.show()

# %%
num_column=df_final.select_dtypes(include=['float64','int64']).columns

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(num_column,1):
    plt.subplot(5, 5, i)
    sns.boxplot(y=df_final[col])
    plt.title(col)
    
plt.tight_layout()
plt.show()

# %%
sns.heatmap(df_final.corr() > 0.8,annot=True,cbar=False) 
plt.show()

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(num_column,1):
    plt.subplot(5, 5, i)
    sns.boxplot(y=df_final[col])
    plt.title(col)
    
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10)) 
sns.lineplot(df_final,ax=axes[0, 1])  # First row, second column
axes[0, 1].set_title('Line Plot')
plt.tight_layout()
plt.show()

# %%
df_final[num_column].hist(bins=10, figsize=(15, 10))
plt.suptitle('Histograms of numerical features')
  
plt.tight_layout()
plt.show()

# %%
df_final['cnt'].hist(bins=30)

plt.title('')
plt.xlabel('rental counts')
plt.ylabel('frequency')
plt.show()

# %%
correlation_matrix = df_final[num_column].corr()

# %%
sns.pairplot
# Out:
# <function seaborn.axisgrid.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)>

# %%
correlation_matrix
# Out:
#              instant        hr   weekday  weathersit       hum  windspeed  \
# instant     1.000000  0.000060  0.008157    0.030439  0.062116  -0.057837
# hr          0.000060  1.000000  0.007531   -0.055802 -0.194853   0.116640
# weekday     0.008157  0.007531  1.000000    0.060007  0.062469  -0.056754
# weathersit  0.030439 -0.055802  0.060007    1.000000  0.539402  -0.177655
# hum         0.062116 -0.194853  0.062469    0.539402  1.000000  -0.385550
# windspeed  -0.057837  0.116640 -0.056754   -0.177655 -0.385550   1.000000
# casual      0.071259  0.204476 -0.047363   -0.096346 -0.259407   0.129392
# registered  0.074993  0.357042  0.020505   -0.119234 -0.229370   0.090059
# cnt         0.081129  0.366047  0.012161   -0.126448 -0.254353   0.103997
# temp1       0.051173  0.180606 -0.068532    0.124058  0.138773  -0.042825
# season           NaN       NaN       NaN         NaN       NaN        NaN
# yr               NaN       NaN       NaN         NaN       NaN        NaN
# ...

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
